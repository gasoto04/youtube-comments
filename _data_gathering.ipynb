# %% [markdown]
# <h1><center> PPOL 5203 Data Science I: Final project <br><br>
# <font color='grey'> Reactions for shocking news <br><br>
# Sam Cohen, Gabriel Soto, Daniel Cardenas </center> <h1>

# %%
# setup
import requests
import os
import pandas as pd
import yt_videos_comments as yt_vc
#Import YouTubeDataAPI
from youtube_api import YouTubeDataAPI
from youtube_api.youtube_api_utils import *
from dotenv import load_dotenv

# %%
api_key = '<api key>'
query = 'Swift, Kelce'
start_date = '2023-09-12'
n_days = 14
df_videos = yt_vc.get_videos_after_ndays(api_key, query, start_date, n_days)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       3 start_date = '2023-09-12'
#       4 n_days = 14
# ----> 5 df_videos = yt_vc.get_videos_after_ndays(api_key, query, start_date, n_days)
#
# File ~\Dropbox\Georgetown\(1) Data science\Final\yt_videos_comments.py:17, in get_videos_after_ndays(api_key, query, start_date, n_days)
#      15 for day in range(0, n_days):
#      16     date = date_start + datetime.timedelta(days=day)
# ---> 17     df = pd.DataFrame(yt.search(q=query, max_results=500, search_type="video", order_by="viewCount",
#      18                                 relevance_language='en',
#      19                                 published_after=datetime.datetime.timestamp(datetime.datetime.combine(date, datetime.datetime.min.time())),
#      20                                 published_before=datetime.datetime.timestamp(datetime.datetime.combine(date, datetime.datetime.max.time()))
#      21                                ))
#      22     df['day'] = day + 1
#      23     df['day_published'] = date
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\youtube_api\youtube_api.py:704, in YouTubeDataAPI.search(self, q, channel_id, max_results, order_by, next_page_token, published_after, published_before, location, location_radius, region_code, safe_search, relevance_language, event_type, topic_id, video_duration, search_type, parser, part, **kwargs)
#     701 if next_page_token:
#     702     http_endpoint += "&pageToken={}".format(next_page_token)
# --> 704 response_json = self._http_request(http_endpoint)
#     705 if response_json.get('items'):
#     706     for item in response_json.get('items'):
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\youtube_api\youtube_api.py:101, in YouTubeDataAPI._http_request(self, http_endpoint, timeout_in_n_seconds)
#      99     print(http_endpoint.replace(self.key, '{API_KEY_PLACEHOLDER}'))
#     100 response = self.session.get(http_endpoint, timeout=self._timeout)
# --> 101 response_json = _load_response(response)
#     102 return response_json
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\youtube_api\youtube_api_utils.py:48, in _load_response(response)
#      43 def _load_response(response):
#      44     '''
#      45     Loads the response to json, and checks for errors.
#      46     '''
# ---> 48     response.raise_for_status()
#      49     response_json = json.loads(response.text)
#      51     return response_json
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\models.py:1021, in Response.raise_for_status(self)
#    1016     http_error_msg = (
#    1017         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1018     )
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://www.googleapis.com/youtube/v3/search?part=snippet&type=video&maxResults=50&order=viewCount&key=AIzaSyCakkcjPuXV3Y2LCNS2dBuZBedV3NHjF18&q=Swift,%20Kelce&publishedAfter=2023-09-12T05:00:00Z&publishedBefore=2023-09-13T04:59:59Z&relevanceLanguage=en

# %%
df_videos.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_videos.shape
#
# NameError: name 'df_videos' is not defined

# %%
df_videos.value_counts('day', sort=False)
# Out:
# day
# 1      15
# 2      36
# 3      19
# 4      45
# 5      19
# 6      19
# 7      21
# 8      27
# 9      48
# 10     57
# 11     31
# 12     18
# 13     83
# 14    193
# dtype: int64

# %%
df_comments = yt_vc.get_comments_all_videos(api_key, df_videos)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:162, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:203, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:211, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:107, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'video_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_comments = yt_vc.get_comments_all_videos(api_key, df_videos)
#
# File ~\Dropbox\Georgetown\(1) Data science\Final\yt_videos_comments.py:47, in get_comments_all_videos(api_key, df_videos, get_replies)
#      45     df_comments = pd.DataFrame(yt.get_video_comments(video_id, get_replies=get_replies))
#      46     cxv_list.append(df_comments)
# ---> 47     df_comments['day'] = df_videos.loc['video_id', 'day']
#      48     df_comments['day_published'] = df_videos.loc['video_id', 'day_published']
#      50 df_comments_all = pd.concat(cxv_list)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:1247, in _LocIndexer._getitem_tuple(self, tup)
#    1245 with suppress(IndexingError):
#    1246     tup = self._expand_ellipsis(tup)
# -> 1247     return self._getitem_lowerdim(tup)
#    1249 # no multi-index, so validate all of the indexers
#    1250 tup = self._validate_tuple_indexer(tup)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer._getitem_lowerdim(self, tup)
#     963 for i, key in enumerate(tup):
#     964     if is_label_like(key):
#     965         # We don't need to check for tuples here because those are
#     966         #  caught by the _is_nested_tuple_indexer check above.
# --> 967         section = self._getitem_axis(key, axis=i)
#     969         # We should never have a scalar section here, because
#     970         #  _getitem_lowerdim is only called after a check for
#     971         #  is_scalar_access, which that would be.
#     972         if section.ndim == self.ndim:
#     973             # we're in the middle of slicing through a MultiIndex
#     974             # revise the key wrt to `section` by inserting an _NS
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:1312, in _LocIndexer._getitem_axis(self, key, axis)
#    1310 # fall thru to straight lookup
#    1311 self._validate_key(key, axis)
# -> 1312 return self._get_label(key, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:1260, in _LocIndexer._get_label(self, label, axis)
#    1258 def _get_label(self, label, axis: int):
#    1259     # GH#5567 this will fail if the label is not present in the axis.
# -> 1260     return self.obj.xs(label, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:4056, in NDFrame.xs(self, key, axis, level, drop_level)
#    4054             new_index = index[loc]
#    4055 else:
# -> 4056     loc = index.get_loc(key)
#    4058     if isinstance(loc, np.ndarray):
#    4059         if loc.dtype == np.bool_:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'video_id'

# %%
query = 'Ukraine, Russia, invasion'
start_date = '2022-02-24'
n_days = 14
df_videos2 = yt_vc.get_videos_after_ndays(api_key, query, start_date, n_days)

# %%
df_videos2
# Out:
#                        channel_title                channel_id  \
# video_id
# AjzMrDla0OA                 BBC News  UC16niRr50-MSBwiO3YDb3RA
# v4_tq3ZfFzE                  The Sun  UCIzXayRP7-P0ANpq-nD-h5g
# PaLO8t9JGTs                    TODAY  UChDKyKQ59fYz3JO2fl0Z6sg
# dZJ7zIB-qhU                 ABC News  UCBi2mrWuNuyYy4gbM6fU18Q
# HaJCwY9YBQ0                 BBC News  UC16niRr50-MSBwiO3YDb3RA
# ...                              ...                       ...
# ZD5ly9IzNC8               Mezmorised  UCWNnXGngfztTX50bQlMGbPw
# heMcmR0P3Kc                  بلادي M  UCixfvopLS0YODd2s2ng5uUA
# EB8va8JF4JU                 The ISRM  UC5tkEco0xuaURn1c6-6W0vg
# gGRIn25psII        Crime War Defense  UCsgl15nuJiXkpe55GkMKnYw
# N38ecoTDGNs  Warthog Defense Español  UC6i9XFC0vn8T7tjwqwumAIA
#
#              video_publish_date  \
# video_id
# AjzMrDla0OA        1.645728e+09
# v4_tq3ZfFzE        1.645730e+09
# PaLO8t9JGTs        1.645726e+09
# dZJ7zIB-qhU        1.645716e+09
# HaJCwY9YBQ0        1.645716e+09
# ...                         ...
# ZD5ly9IzNC8        1.653607e+09
# heMcmR0P3Kc        1.653626e+09
# EB8va8JF4JU        1.653570e+09
# gGRIn25psII        1.653607e+09
# N38ecoTDGNs        1.653617e+09
#
#                                                    video_title  \
# video_id
# AjzMrDla0OA  Fireball after Russian missile hits airport in...
# v4_tq3ZfFzE  Swarm of Russian helicopter gunships blitzing ...
# PaLO8t9JGTs        Russia Launches Attack On Ukraine Overnight
# dZJ7zIB-qhU  Russian forces begin their attack, Ukraine now...
# HaJCwY9YBQ0  CCTV shows tanks and Russian military vehicles...
# ...                                                        ...
# ZD5ly9IzNC8  LIVE: UKRAINE RUSSIA WAR 24/7 LIVE CAMS OF THE...
# heMcmR0P3Kc  Ukrainian soldiers digging trenches #ukraine #...
# EB8va8JF4JU  The Human Security Side of Displaced Victims o...
# gGRIn25psII  RUSSIAN INVASION: Russian Chechen Forces Battl...
# N38ecoTDGNs  HOW HARD WILL IT BE TO DEFEND UKRAINE FROM RUS...
#
#                                              video_description video_category  \
# video_id
# AjzMrDla0OA  Russian forces have launched a military assaul...             25
# v4_tq3ZfFzE  CHILLING video on Thursday appears to show the...             25
# PaLO8t9JGTs  Overnight, Russia launched its long-awaited at...             25
# dZJ7zIB-qhU  Russian President Vladimir Putin warned other ...             25
# HaJCwY9YBQ0  Russia has invaded Ukraine, advancing on the c...             25
# ...                                                        ...            ...
# ZD5ly9IzNC8  You can help support the stream and Mezmorised...             25
# heMcmR0P3Kc  The map is the latest ISW update on the situat...             25
# EB8va8JF4JU  The ISRM Houston Chapter - The Human Security ...             27
# gGRIn25psII  More Footage Of Russian Chechen Forces Battlin...             22
# N38ecoTDGNs  How hard will it be for Ukraine to defend itse...             27
#
#             video_view_count video_comment_count video_like_count  \
# video_id
# AjzMrDla0OA         16690670               31334           135931
# v4_tq3ZfFzE          9311573                8140            62902
# PaLO8t9JGTs          3670956                6735            35562
# dZJ7zIB-qhU          3144791               10923            31088
# HaJCwY9YBQ0          2859358                9257            30021
# ...                      ...                 ...              ...
# ZD5ly9IzNC8              374                   0                3
# heMcmR0P3Kc              215                   1                7
# EB8va8JF4JU               77                   0                0
# gGRIn25psII 2023-11-23 13:39:33.438436   14    2022-05-26 2022-05-26 23:20:21
# N38ecoTDGNs 2023-11-23 13:39:33.438436   14    2022-05-26 2022-05-27 02:00:08
#
# [312 rows x 16 columns]

# %%
df_videos2.value_counts('day_published')
# Out:
# day_published
# 2022-02-24    76
# 2022-02-25    60
# 2022-02-27    34
# 2022-03-02    26
# 2022-03-06    22
# 2022-04-10    19
# 2022-05-13    15
# 2022-03-17    12
# 2022-03-24    10
# 2022-04-20    10
# 2022-05-26    10
# 2022-03-11     9
# 2022-05-01     7
# 2022-04-01     2
# dtype: int64

# %%
# create a client 
# this is what we call: instantiate the class
api_key = 'AIzaSyCJC4HcMkrM-cj9p0Jp5E1OWAGbn6WVnZE'
yt = YouTubeDataAPI(api_key)



# https://www.harpersbazaar.com/celebrity/latest/a45301082/taylor-swift-travis-kelce-full-relationship-timeline/
df = pd.DataFrame(yt.search(q='Swift, Kelce', max_results=10000, search_type="video", order_by="viewCount", 
                            relevance_language='en',
                            publishedAfter="2023-09-12T00:00:00Z", publishedBefore="2023-09-17T00:00:00Z"))
df['publish_date'] = pd.to_timedelta(df['video_publish_date'], unit='s') + pd.to_datetime('1970-1-1')
print(df.keys(), df.shape)
df[["channel_title", "video_title", 'publish_date', 'video_category']]
# Out:
# Index(['video_id', 'channel_title', 'channel_id', 'video_publish_date',
#        'video_title', 'video_description', 'video_category', 'video_thumbnail',
#        'collection_date', 'publish_date'],
#       dtype='object') (133, 10)
#         channel_title                                        video_title  \
# 0         New Heights  ⚠️ WARNING ⚠️ Living with Jason Kelce may caus...
# 1         New Heights  Jason really tried to blame his KELCE premiere...
# 2               TODAY  Eagles&#39; Jason Kelce pulls back curtain on ...
# 3         ESPN Shorts           Taylor Swift and Travis Kelce ❤️ #shorts
# 4            HangTime  Taylor Swift is dating Travis Kelce! #shorts #...
# ..                ...                                                ...
# 128  Giving Gratitude  Taylor Swift has recently started dating NFL S...
# 129     Viral Factory  Unveiling the Secrets of Travis Kelce and Tayl...
# 130     𝐆𝐨𝐬𝐬𝐢𝐩 𝐆𝐚𝐥𝐚𝐱𝐲  Travis Kelce Just ‘Having Fun’ Amid Taylor Swi...
# 131        Quick News  Travis Kelce s Dating Life Sparks Rumors, with...
# 132          News 24H  Are Taylor Swift and Travis Kelce Dating? His ...
#
#            publish_date video_category
# 0   2023-09-15 22:00:19           None
# 1   2023-09-14 01:05:12           None
# 2   2023-09-12 20:00:14           None
# 3   2023-09-13 22:45:00           None
# 4   2023-09-15 19:16:24           None
# ..                  ...            ...
# 128 2023-09-15 05:52:37           None
# 129 2023-09-16 00:03:55           None
# 130 2023-09-16 00:27:24           None
# 131 2023-09-16 23:52:39           None
# 132 2023-09-15 19:24:57           None
#
# [133 rows x 4 columns]

# %%
video_list = list(df['video_id'])
df_videos = pd.DataFrame(yt.get_video_metadata(video_list))
print(df_videos.shape)
df_videos.dropna(subset=['video_comment_count'], inplace=True)
print(df_videos.keys(), df_videos.shape)
video_list = list(df_videos['video_id'])
df_videos.head(31)
# Out:
# (133, 14)
# Index(['video_id', 'channel_title', 'channel_id', 'video_publish_date',
#        'video_title', 'video_description', 'video_category',
#        'video_view_count', 'video_comment_count', 'video_like_count',
#        'video_dislike_count', 'video_thumbnail', 'video_tags',
#        'collection_date'],
#       dtype='object') (132, 14)
#        video_id                                   channel_title  \
# 0   IbwVmWri4_M                                     New Heights
# 1   1jqHtmNa5jg                                     New Heights
# 2   CycfFobNPlI                                           TODAY
# 3   K2w5rh0hQWs                                     ESPN Shorts
# 4   LdhKLE96XS4                                        HangTime
# 5   YlhE3py9HrE                            New York Post Sports
# 6   -XNwzI4H0Hc                             The Rich Eisen Show
# 7   GjmvWRUclEQ                            Petey’s Picks Sports
# 8   9v05mWeDBhU                                            ESPN
# 9   sNCQU6t5UzY                                            ESPN
# 10  3UZvxkEhPEU                                            ESPN
# 11  1Zzxst94SQ4                               DailySportsDosage
# 12  leeNx_QNwFI                                  Shallon Lester
# 13  _FhUlzQYRd4                                         E! News
# 14  2Bkg5Gv1ZlU                           Entertainment Tonight
# 15  SpKnXopkWFs                                   Brianna Diogo
# 16  wCfX42BO9Pw  Arrowhead Addict: A Kansas City Chiefs Podcast
# 17  e6DGMDxQvC8                                 Real Alex Clark
# 18  xnl5gIQ-J84                                   Sneaky Sports
# 19  NrS5ydXlTL0                                    LeBatardShow
# 20  4n58jEM3kpU                            Chicks in the Office
# 21  25vcFXFi0LA                                         OutKick
# 22  BVEEqH7zc9k                            The Thomas Mott Show
# 23  ianpGHGh5h8                                Access Hollywood
# 24  KqKWegCWuZQ                                Red Tribe Cinema
# 25  2iHwF-VnWO8                               Rob Has a Podcast
# 26  7NGlMRN95W8                                 What's Trending
# 27  8eEOBudtrEY                                  X17onlineVideo
# 28  2cgSHwTbUWg                             FOX 5 Washington DC
# 30  APd7Mjrd1OU                                      RiRi's Tea
# 31  Se0CAl8WaRI                                   The LNX Files
#
#                   channel_id  video_publish_date  \
# 0   UCVRm2Ho8cL3lvWDyp2ayuFw        1.694815e+09
# 1   UCVRm2Ho8cL3lvWDyp2ayuFw        1.694654e+09
# 2   UChDKyKQ59fYz3JO2fl0Z6sg        1.694549e+09
# 3   UCzq7Lv8Rflx055QdUtfuLZA        1.694645e+09
# 4   UCdIFTflafikgEEUuKZia3jQ        1.694805e+09
# 5   UCR7hOJFBzhEpgwBL_HJVteA        1.694806e+09
# 6   UCqMtxjKnR7ySbEZSs2N-v0Q        1.694651e+09
# 7   UCeFDq17cnplxyty7F69Pwpw        1.694661e+09
# 8   UCiWLfSweyRNmLpgEHekhoAg        1.694657e+09
# 9   UCiWLfSweyRNmLpgEHekhoAg        1.694566e+09
# 10  UCiWLfSweyRNmLpgEHekhoAg        1.694818e+09
# 11  UC_4MHQy18oruEu_F6GiOQ_Q        1.694826e+09
# 12  UCygmWL3k4EpxBmWGGBs5ldw        1.694729e+09
# 13  UCjDsbbzHgTrGc4Ff26TJtsA        1.694815e+09
# 14  UCdtXPiqI2cLorKaPrfpKc4g        1.694651e+09
# 15  UCFlUByMJmqjFzR5S6J2lXEw        1.694577e+09
# 16  UC3CdquRsu60VZcbGMfr1WgQ        1.694631e+09
# 17  UCcbPQtclBJp_8se9a2t8AoA        1.694914e+09
# 3  2023-11-23 11:29:00.269028
# 4  2023-11-23 11:29:00.269028
# 5  2023-11-23 11:29:00.269028
# 6  2023-11-23 11:29:00.269028
# 7  2023-11-23 11:29:00.270032
# 8  2023-11-23 11:29:00.270032
# 9  2023-11-23 11:29:00.270032
# 10 2023-11-23 11:29:00.270032
# 11 2023-11-23 11:29:00.270032
# 12 2023-11-23 11:29:00.270032
# 13 2023-11-23 11:29:00.270032
# 14 2023-11-23 11:29:00.270032
# 15 2023-11-23 11:29:00.270032
# 16 2023-11-23 11:29:00.270032
# 17 2023-11-23 11:29:00.270032
# 18 2023-11-23 11:29:00.270032
# 19 2023-11-23 11:29:00.270032
# 20 2023-11-23 11:29:00.270032
# 21 2023-11-23 11:29:00.270032
# 22 2023-11-23 11:29:00.270032
# 23 2023-11-23 11:29:00.270032
# 24 2023-11-23 11:29:00.270032
# 25 2023-11-23 11:29:00.270032
# 26 2023-11-23 11:29:00.270032
# 27 2023-11-23 11:29:00.270032
# 28 2023-11-23 11:29:00.270032
# 30 2023-11-23 11:29:00.270032
# 31 2023-11-23 11:29:00.270032

# %%
cxv_list = []
for video_id in video_list:
    df_comments = pd.DataFrame(yt.get_video_comments(video_id, get_replies=False))
    cxv_list.append(df_comments)
    # print(len(cxv_list), df_comments.shape, video_id)
df_comments_all = pd.concat(cxv_list)
df_comments_all['publish_date'] = pd.to_timedelta(df_comments_all['comment_publish_date'], unit='s') + pd.to_datetime('1970-1-1')
df_comments_all
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'comment_publish_date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 7
#       5     # print(len(cxv_list), df_comments.shape, video_id)
#       6 df_comments_all = pd.concat(cxv_list)
# ----> 7 df_comments['publish_date'] = pd.to_timedelta(df_comments['comment_publish_date'], unit='s') + pd.to_datetime('1970-1-1')
#       8 df_comments_all
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'comment_publish_date'

# %%
df_comments_all['publish_date'] = pd.to_timedelta(df_comments_all['comment_publish_date'], unit='s') + pd.to_datetime('1970-1-1')
df_comments_all
# Out:
#        video_id                              commenter_channel_url  \
# 0   IbwVmWri4_M  http://www.youtube.com/channel/UCVdbyQ7f5eUrVU...
# 1   IbwVmWri4_M  http://www.youtube.com/channel/UCn49e05S1rK4tG...
# 2   IbwVmWri4_M  http://www.youtube.com/channel/UCNXvE3oe_NzT_e...
# 3   IbwVmWri4_M  http://www.youtube.com/channel/UCs2uOfQjzZaaF4...
# 4   IbwVmWri4_M  http://www.youtube.com/channel/UCL09DVME2h3Gcx...
# ..          ...                                                ...
# 1   XwcRYYtcs1A  http://www.youtube.com/channel/UCtSCMs9Mm6TQP0...
# 2   XwcRYYtcs1A  http://www.youtube.com/channel/UCtSCMs9Mm6TQP0...
# 0   XZkNXjzeYq0  http://www.youtube.com/channel/UCD8iKrvVkZ9CBy...
# 0   gnaHvHs8z-E  http://www.youtube.com/channel/UCQSa4HTLRfrEfb...
# 0   AnSkai6mLdU  http://www.youtube.com/channel/UCzZH6x9nAdG8D0...
#
#         commenter_channel_id commenter_channel_display_name  \
# 0   UCVdbyQ7f5eUrVUmk2lfSbuw                  Mindy Nickels
# 1   UCn49e05S1rK4tGKrZEJduhQ                  Bruce Asborno
# 2   UCNXvE3oe_NzT_ekLD1l2lQQ                    Mark Barlow
# 3   UCs2uOfQjzZaaF4moZC7_69g                    King Gringo
# 4   UCL09DVME2h3GcxmRvr8jsFg                  James Edwards
# ..                       ...                            ...
# 1   UCtSCMs9Mm6TQP0GjcHybSqQ                         taytay
# 2   UCtSCMs9Mm6TQP0GjcHybSqQ                         taytay
# 0   UCD8iKrvVkZ9CByAfLvT9Ang                        Henry M
# 0   UCQSa4HTLRfrEfbfF7AYd1Tg                       MyMusing
# 0   UCzZH6x9nAdG8D0U4djjQ07w                       Stef. BL
#
#                     comment_id  comment_like_count  comment_publish_date  \
# 0   UgwMsmbAhmy0KGAUggR4AaABAg                   0          1.700776e+09
# 1   Ugw_hsMvG8q1ZnrqGMZ4AaABAg                   0          1.700772e+09
# 2   Ugx1H_sKZ1I79eSVDTZ4AaABAg                   0          1.700770e+09
# 3   Ugw9e1pQtCi1pLtnW7d4AaABAg                   0          1.700769e+09
# 4   Ugx3syG9R_1ShUWMJqt4AaABAg                   0          1.700734e+09
# ..                         ...                 ...                   ...
# 1   Ugxi2iDSh7zbdk1cO2x4AaABAg                   2          1.694852e+09
# 2   UgzXyZdLBFQNcgnI4_V4AaABAg                   3          1.694780e+09
# 0   UgznlUoejF9KMJMGxEt4AaABAg                   0          1.698504e+09
# 0   UgzDGmD-BdPxSuX5BmB4AaABAg                   1          1.694885e+09
# 0   UgzJkzwc8mi86sHkVtF4AaABAg                   0          1.695973e+09
#
#                                                  text commenter_rating  \
# 0   At least it’s not done in anger…\nLove seeing ...             none
# 1    If that’s all she has then he’s doing very well.             none
# 2   I listened to a Freakonomics Radio podcast int...             none
# 3   Well if he's the man i hope he is nothing will...             none
# 4       *insert gif of Jason yelling in cowboys face*             none
# ..                                                ...              ...
# 1           You were right TS pr denied the rumours !             none
# 2   can you read what is joe is thinking about tay...             none
# 0                                        🤣 *promo sm*             none
# 0                                 Like And Subscribe!             none
# 0   No había visto esto, pero ahora sé que la info...             none
#
#    comment_parent_id            collection_date  reply_count  \
# 0               None 2023-11-23 11:45:47.819175            0
# 1               None 2023-11-23 11:45:47.819175            0
# 2               None 2023-11-23 11:45:47.819175            0
# 3               None 2023-11-23 11:45:47.819175            0
# 4               None 2023-11-23 11:45:47.819175            0
# ..               ...                        ...          ...
# 1               None 2023-11-23 11:46:02.562318            2
# 2               None 2023-11-23 11:46:02.562318            3
# 0               None 2023-11-23 11:46:03.392995            0
# 0               None 2023-11-23 11:46:03.957267            0
# 0               None 2023-11-23 11:46:04.521237            0
#
#           publish_date
# 0  2023-11-23 21:39:35
# 1  2023-11-23 20:34:19
# 2  2023-11-23 19:59:51
# 3  2023-11-23 19:42:16
# 4  2023-11-23 09:59:24
# ..                 ...
# 1  2023-09-16 08:14:20
# 2  2023-09-15 12:05:14
# 0  2023-10-28 14:41:21
# 0  2023-09-16 17:24:24
# 0  2023-09-29 07:30:45
#
# [2797 rows x 13 columns]

# %%
df_comments_all.iloc()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (0, 4)
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 df_comments_all[0,4]
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: (0, 4)
