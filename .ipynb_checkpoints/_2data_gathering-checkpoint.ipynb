# %% [markdown]
# <h1><center> PPOL 5203 Data Science I: Final project <br><br>
# <font color='grey'> Reactions for shocking news <br><br>
# Sam Cohen, Gabriel Soto, Daniel Cardenas </center> <h1>

# %%
# setup
import requests
import os
import pandas as pd
import yt_videos_comments as yt_vc
#Import YouTubeDataAPI
from youtube_api import YouTubeDataAPI
from youtube_api.youtube_api_utils import *
from dotenv import load_dotenv

# %% [markdown]
# ### Pop News: Taylor Swift and Travis Kelce - Video data

# %%
api_key = "AIzaSyDdEt_E4ErXjP158Xg_yxAXK6VWSNATc1I"
#AIzaSyCakkcjPuXV3Y2LCNS2dBuZBedV3NHjF18
#AIzaSyDdEt_E4ErXjP158Xg_yxAXK6VWSNATc1I
query = 'Swift, Kelce'
start_date = '2023-09-12'
n_days = 14
df_videos = yt_vc.get_videos_after_ndays(api_key, query, start_date, n_days)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[13], line 7
#       5 start_date = '2023-09-12'
#       6 n_days = 14
# ----> 7 df_videos = yt_vc.get_videos_after_ndays(api_key, query, start_date, n_days)
#
# File ~\OneDrive\Georgetown\2023\Fall\data science\youtube-comments\yt_videos_comments.py:17, in get_videos_after_ndays(api_key, query, start_date, n_days)
#      15 for day in range(0, n_days):
#      16     date = date_start + datetime.timedelta(days=day)
# ---> 17     df = pd.DataFrame(yt.search(q=query, max_results=500, search_type="video", order_by="viewCount",
#      18                                 relevance_language='en',
#      19                                 published_after=datetime.datetime.timestamp(datetime.datetime.combine(date, datetime.datetime.min.time())),
#      20                                 published_before=datetime.datetime.timestamp(datetime.datetime.combine(date, datetime.datetime.max.time()))
#      21                                ))
#      22     df['day'] = day + 1
#      23     df['day_published'] = date
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\youtube_api\youtube_api.py:704, in YouTubeDataAPI.search(self, q, channel_id, max_results, order_by, next_page_token, published_after, published_before, location, location_radius, region_code, safe_search, relevance_language, event_type, topic_id, video_duration, search_type, parser, part, **kwargs)
#     701 if next_page_token:
#     702     http_endpoint += "&pageToken={}".format(next_page_token)
# --> 704 response_json = self._http_request(http_endpoint)
#     705 if response_json.get('items'):
#     706     for item in response_json.get('items'):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\youtube_api\youtube_api.py:101, in YouTubeDataAPI._http_request(self, http_endpoint, timeout_in_n_seconds)
#      99     print(http_endpoint.replace(self.key, '{API_KEY_PLACEHOLDER}'))
#     100 response = self.session.get(http_endpoint, timeout=self._timeout)
# --> 101 response_json = _load_response(response)
#     102 return response_json
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\youtube_api\youtube_api_utils.py:48, in _load_response(response)
#      43 def _load_response(response):
#      44     '''
#      45     Loads the response to json, and checks for errors.
#      46     '''
# ---> 48     response.raise_for_status()
#      49     response_json = json.loads(response.text)
#      51     return response_json
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\models.py:1021, in Response.raise_for_status(self)
#    1016     http_error_msg = (
#    1017         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1018     )
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://www.googleapis.com/youtube/v3/search?part=snippet&type=video&maxResults=50&order=viewCount&key=AIzaSyDdEt_E4ErXjP158Xg_yxAXK6VWSNATc1I&q=Swift,%20Kelce&publishedAfter=2023-09-12T04:00:00Z&publishedBefore=2023-09-13T03:59:59Z&relevanceLanguage=en

# %%
df_videos.shape
# Out:
# (425, 16)

# %%
df_videos.value_counts('day', sort=False)
# Out:
# day
# 1     11
# 2     33
# 3     24
# 4     43
# 5     18
# 6     20
# 7     24
# 8     30
# 9     45
# 10    61
# 11    31
# 12    19
# 13    20
# 14    46
# dtype: int64

# %%
df_videos.to_csv('swift_pop_videodata.csv', index=False)

# %% [markdown]
# ### Pop News: Taylor Swift and Travis Kelce - Comment data

# %%
df_comments = yt_vc.get_comments_all_videos(api_key, df_videos)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df_comments = yt_vc.get_comments_all_videos(api_key, df_videos)
#
# File ~\OneDrive\Georgetown\2023\Fall\data science\youtube-comments\yt_videos_comments.py:41, in get_comments_all_videos(api_key, df_videos, get_replies)
#      40 def get_comments_all_videos(api_key, df_videos, get_replies=False):
# ---> 41     yt = YouTubeDataAPI(api_key)
#      42     cxv_list = []
#      43     df_videos['video_id'] = df_videos.index
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\youtube_api\youtube_api.py:47, in YouTubeDataAPI.__init__(self, key, api_version, verify_api_key, verbose, timeout)
#      45     raise ValueError('No API key used to initate the class.')
#      46 if verify_api_key and not self.verify_key():
# ---> 47     raise ValueError('The API Key is invalid')
#      49 # creates a requests sessions for API calls.
#      50 self._create_session()
#
# ValueError: The API Key is invalid

# %%
pop_comments = yt_vc.get_comments_all_videos(api_key, df_videos, get_replies=False)
pop_comments.to_csv('swift_pop_comments.csv', index=False)

# %% [markdown]
# ### Horrific News: Russia-Ukraine War - Video data

# %%
query = 'Ukraine, Russia, invasion'
start_date = '2022-02-24'
n_days = 14
df_videos2 = yt_vc.get_videos_after_ndays(api_key, query, start_date, n_days)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[42], line 4
#       2 start_date = '2022-02-24'
#       3 n_days = 14
# ----> 4 df_videos2 = yt_vc.get_videos_after_ndays(api_key, query, start_date, n_days)
#
# File ~\Downloads\yt_videos_comments.py:17, in get_videos_after_ndays(api_key, query, start_date, n_days)
#      15 for day in range(0, n_days):
#      16     date = date_start + datetime.timedelta(days=day)
# ---> 17     df = pd.DataFrame(yt.search(q=query, max_results=500, search_type="video", order_by="viewCount",
#      18                                 relevance_language='en',
#      19                                 published_after=datetime.datetime.timestamp(datetime.datetime.combine(date, datetime.datetime.min.time())),
#      20                                 published_before=datetime.datetime.timestamp(datetime.datetime.combine(date, datetime.datetime.max.time()))
#      21                                ))
#      22     df['day'] = day + 1
#      23     df['day_published'] = date
#
# File ~\anaconda4\Lib\site-packages\youtube_api\youtube_api.py:704, in YouTubeDataAPI.search(self, q, channel_id, max_results, order_by, next_page_token, published_after, published_before, location, location_radius, region_code, safe_search, relevance_language, event_type, topic_id, video_duration, search_type, parser, part, **kwargs)
#     701 if next_page_token:
#     702     http_endpoint += "&pageToken={}".format(next_page_token)
# --> 704 response_json = self._http_request(http_endpoint)
#     705 if response_json.get('items'):
#     706     for item in response_json.get('items'):
#
# File ~\anaconda4\Lib\site-packages\youtube_api\youtube_api.py:101, in YouTubeDataAPI._http_request(self, http_endpoint, timeout_in_n_seconds)
#      99     print(http_endpoint.replace(self.key, '{API_KEY_PLACEHOLDER}'))
#     100 response = self.session.get(http_endpoint, timeout=self._timeout)
# --> 101 response_json = _load_response(response)
#     102 return response_json
#
# File ~\anaconda4\Lib\site-packages\youtube_api\youtube_api_utils.py:48, in _load_response(response)
#      43 def _load_response(response):
#      44     '''
#      45     Loads the response to json, and checks for errors.
#      46     '''
# ---> 48     response.raise_for_status()
#      49     response_json = json.loads(response.text)
#      51     return response_json
#
# File ~\anaconda4\Lib\site-packages\requests\models.py:1021, in Response.raise_for_status(self)
#    1016     http_error_msg = (
#    1017         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1018     )
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://www.googleapis.com/youtube/v3/search?part=snippet&type=video&maxResults=50&order=viewCount&key=AIzaSyAkbD5Fxf8TtrlTy-b6wagZ4I2M5fdUofc&q=Ukraine,%20Russia,%20invasion&publishedAfter=2022-02-24T05:00:00Z&publishedBefore=2022-02-25T04:59:59Z&relevanceLanguage=en

# %%
df_videos2
# Out:
#                                          channel_title  \
# video_id
# AjzMrDla0OA                                   BBC News
# v4_tq3ZfFzE                                    The Sun
# PaLO8t9JGTs                                      TODAY
# dZJ7zIB-qhU                                   ABC News
# OBVdAslh89E                                   NBC News
# ...                                                ...
# ey13lItyKh4                                SEKLEBET-ID
# aE1bhjE_fGs                                    Julyana
# EI7sZByoEE8                            highprogressive
# l0gI08arxDE                 Mykolas Romeris University
# 8y9IuCYjwDw  College of Arts and Sciences - Kent State
#
#                            channel_id  video_publish_date  \
# video_id
# AjzMrDla0OA  UC16niRr50-MSBwiO3YDb3RA        1.645728e+09
# v4_tq3ZfFzE  UCIzXayRP7-P0ANpq-nD-h5g        1.645730e+09
# PaLO8t9JGTs  UChDKyKQ59fYz3JO2fl0Z6sg        1.645726e+09
# dZJ7zIB-qhU  UCBi2mrWuNuyYy4gbM6fU18Q        1.645716e+09
# OBVdAslh89E  UCeY0bbntWzzVIaj2z3QigXg        1.645767e+09
# ...                               ...                 ...
# ey13lItyKh4  UCSS42GP58-jKV_1q8fGEsgA        1.646867e+09
# aE1bhjE_fGs  UCgeTGVGy8-RDj8RpLw5Nngw        1.646854e+09
# EI7sZByoEE8  UCYyqME5AJIQ5EFSkO-m8eKA        1.646856e+09
# l0gI08arxDE  UCxfax0AIeX5VQ_eZuFVwrdg        1.646900e+09
# 8y9IuCYjwDw  UCmBWmQo3-v1UvrLlc4UXp8A        1.646866e+09
#
#                                                    video_title  \
# video_id
# AjzMrDla0OA  Fireball after Russian missile hits airport in...
# v4_tq3ZfFzE  Swarm of Russian helicopter gunships blitzing ...
# PaLO8t9JGTs        Russia Launches Attack On Ukraine Overnight
# dZJ7zIB-qhU  Russian forces begin their attack, Ukraine now...
# OBVdAslh89E     Russia Launches Full-Scale Invasion of Ukraine
# ...                                                        ...
# ey13lItyKh4  Pasukan lengan kuning Ukraina terkena tembakan...
# aE1bhjE_fGs  Julyana - RECLAIM YOURSELF -  Ukraine after Ru...
# EI7sZByoEE8  These Youtubers Are LYING About Russia's Invas...
# l0gI08arxDE  Russia's Invasion of Ukraine: International La...
# 8y9IuCYjwDw  Russia's Invasion of Ukraine: History, Politic...
#
#                                              video_description video_category  \
# video_id
# AjzMrDla0OA  Russian forces have launched a military assaul...             25
# v4_tq3ZfFzE  CHILLING video on Thursday appears to show the...             25
# PaLO8t9JGTs  Overnight, Russia launched its long-awaited at...             25
# dZJ7zIB-qhU  Russian President Vladimir Putin warned other ...             25
# OBVdAslh89E  Russia launched multiple attacks across Ukrain...             25
# ...                                                        ...            ...
# ey13lItyKh4                                                                22
# aE1bhjE_fGs  When 20 years ago I came abroad, people often ...             10
# EI7sZByoEE8  These three self-described "patriotic socialis...             23
# l0gI08arxDE  Russia's aggresive war against Ukraine is unpr...             24
# ...                                ...  ...           ...                 ...
# ey13lItyKh4 2023-11-28 11:34:19.987352   14    2022-03-09 2022-03-09 22:58:18
# aE1bhjE_fGs 2023-11-28 11:34:19.987352   14    2022-03-09 2022-03-09 19:22:05
# EI7sZByoEE8 2023-11-28 11:34:19.987352   14    2022-03-09 2022-03-09 20:00:08
# l0gI08arxDE 2023-11-28 11:34:19.987352   14    2022-03-09 2022-03-10 08:05:49
# 8y9IuCYjwDw 2023-11-28 11:34:19.987352   14    2022-03-09 2022-03-09 22:40:52
#
# [399 rows x 16 columns]

# %%
df_videos2.value_counts('day_published')
# Out:
# day_published
# 2022-02-24    76
# 2022-02-25    60
# 2022-02-27    34
# 2022-03-02    26
# 2022-03-06    22
# 2022-04-10    19
# 2022-05-13    15
# 2022-03-17    12
# 2022-03-24    10
# 2022-04-20    10
# 2022-05-26    10
# 2022-03-11     9
# 2022-05-01     7
# 2022-04-01     2
# dtype: int64

# %%
df_videos2.to_csv('ukraine_horrific_videodata.csv', index=False)

# %% [markdown]
# ### Horrific News: Russia-Ukraine War - Comment data

# %%
horrific_comments = yt_vc.get_comments_all_videos(api_key, df_videos2, get_replies=False)
horrific_comments.to_csv('ukraine_horrific_comments.csv', index=False)

# %% [markdown]
# ### Scandalous News: Menendez Indictment - Video data

# %%
query = 'Menendez, indictment, bribe'
start_date = '2023-09-22'
n_days = 14
df_videos3 = yt_vc.get_videos_after_ndays(api_key, query, start_date, n_days)
# Out:
# 0 2023-09-22 00:00:00 207
# 1 2023-09-23 00:00:00 66
# 2 2023-09-24 00:00:00 15
# 3 2023-09-25 00:00:00 110
# 4 2023-09-26 00:00:00 31
# 5 2023-09-27 00:00:00 39
# 6 2023-09-28 00:00:00 16
# 7 2023-09-29 00:00:00 9
# 8 2023-09-30 00:00:00 3
# 9 2023-10-01 00:00:00 2
# 10 2023-10-02 00:00:00 4
# 11 2023-10-03 00:00:00 1
# 12 2023-10-04 00:00:00 2
# 13 2023-10-05 00:00:00 5

# %%
df_videos3.value_counts('day', sort=False)
# Out:
# day
# 1     201
# 2      65
# 3      14
# 4     108
# 5      31
# 6      39
# 7      16
# 8       9
# 9       3
# 10      2
# 11      4
# 12      1
# 13      2
# 14      5
# dtype: int64

# %%
df_videos3
# Out:
#                                      channel_title                channel_id  \
# video_id
# u1l2dbqP7oA                                    CNN  UCupvZG-5ko_eiXAupbDfxWw
# 0hNDqyTeqhk                 Eyewitness News ABC7NY  UCrlIS7z20CnVaCrMvdkig_g
# pPaTYq09nqg                                    CNN  UCupvZG-5ko_eiXAupbDfxWw
# vMW84jY5Ack                               Fox News  UCXIJgqnII2ZOINSWNOGFThA
# n8SQdCSnuuE                               Fox News  UCXIJgqnII2ZOINSWNOGFThA
# ...                                            ...                       ...
# rGVcog56fQs                          New York Post  UCrvhNP_lWuPIP6QZzJmM-bw
# gLgTLVGwz5k  Joseph Firestone Empowering Democracy  UCgtM_tmbkNf_64nH1fo48TQ
# jpq-EnffIac                         TrendyFlix USA  UCWXmnfef_3AF-g9ydVleJ3g
# Y--GRsfAe9o                              hats0fyou  UC5ihaHtqxMaQwCcnY4TexwQ
# SsYx8_-kaLQ                             catty news  UC4DC_ogWXR3veQODauNR6Ig
#
#              video_publish_date  \
# video_id
# u1l2dbqP7oA        1.695414e+09
# 0hNDqyTeqhk        1.695455e+09
# pPaTYq09nqg        1.695408e+09
# vMW84jY5Ack        1.695448e+09
# n8SQdCSnuuE        1.695431e+09
# ...                         ...
# rGVcog56fQs        1.696526e+09
# gLgTLVGwz5k        1.696532e+09
# jpq-EnffIac        1.696558e+09
# Y--GRsfAe9o        1.696550e+09
# SsYx8_-kaLQ        1.696498e+09
#
#                                                    video_title  \
# video_id
# u1l2dbqP7oA  US attorney: Agents discovered 'a lot of gold'...
# 0hNDqyTeqhk  Sen. Bob Menendez, wife indicted; Murphy calls...
# pPaTYq09nqg  Sen. Bob Menendez and wife indicted on bribery...
# vMW84jY5Ack  Jesse Watters: Biden's admin is taking down Bo...
# n8SQdCSnuuE  'STUNNING': Kayleigh McEnany on Dem senator ch...
# ...                                                        ...
# rGVcog56fQs  Bob Menendez allegedly took Mercedes bribe aft...
# gLgTLVGwz5k  Empowering Democracy: Dump The Corruption; Rob...
# jpq-EnffIac  Deadly crash involving Nadine Menendez cited i...
# Y--GRsfAe9o  Egypt faces scrutiny in US after Senator Menen...
# SsYx8_-kaLQ  Democrat Sen Menendez's wife hit, killed pedes...
#
#                                              video_description video_category  \
# video_id
# u1l2dbqP7oA  US Attorney Damian Williams announced corrupti...             25
# 0hNDqyTeqhk  A federal grand jury in New York has returned ...             25
# pPaTYq09nqg  New Jersey Democratic Sen. Bob Menendez was ch...             25
# vMW84jY5Ack  FOX News host Jesse Watters breaks down the al...             25
# n8SQdCSnuuE  ‘Outnumbered’ panel discusses the federal indi...             25
# ...                                                        ...            ...
# rGVcog56fQs  Indicted New Jersey Sen. Bob Menendez — accuse...             25
# gLgTLVGwz5k  Senator Robert Menendez (D-NJ) faces an indict...             24
# jpq-EnffIac  Welcome to TrendyFlix USA, your ultimate desti...             24
# Y--GRsfAe9o  Egypt faces scrutiny in US after Senator Menen...             25
# SsYx8_-kaLQ  #DemocratSen #Menendezs #wifehit\nAccording to...             25
#
#             video_view_count video_comment_count video_like_count  \
# video_id
# u1l2dbqP7oA           639860                3541             6339
# 0hNDqyTeqhk           398304                2695             2722
# pPaTYq09nqg           395631                4246             3975
# vMW84jY5Ack           337735                1920             6944
# n8SQdCSnuuE           287541                2361             6065
# ...                      ...                 ...              ...
# rGVcog56fQs            41235                 131              249
# gLgTLVGwz5k               10                   0                5
# jpq-EnffIac                7                   0                0
# Y--GRsfAe9o                4                   0                0
# SsYx8_-kaLQ                3                   0                0
#
#             video_dislike_count  \
# video_id
# u1l2dbqP7oA                None
# 0hNDqyTeqhk                None
# pPaTYq09nqg                None
# vMW84jY5Ack                None
# n8SQdCSnuuE                None
# ...                         ...
# rGVcog56fQs                None
# gLgTLVGwz5k                None
# jpq-EnffIac                None
# Y--GRsfAe9o                None
# SsYx8_-kaLQ                None
#
#                                               video_thumbnail  \
# video_id
# u1l2dbqP7oA  https://i.ytimg.com/vi/u1l2dbqP7oA/hqdefault.jpg
# %%
sentiment_menendez.head()
# Out:
#       video_id                              commenter_channel_url  \
# 0  u1l2dbqP7oA  http://www.youtube.com/channel/UCeWYnjrT3_rDlA...
# 1  u1l2dbqP7oA  http://www.youtube.com/channel/UCNwV1VD6TAz5an...
# 2  u1l2dbqP7oA  http://www.youtube.com/channel/UCgvLGMHYXTWsqJ...
# 3  u1l2dbqP7oA  http://www.youtube.com/channel/UCT5oH7xY930PZl...
# 4  u1l2dbqP7oA  http://www.youtube.com/channel/UCL1FJuJ8Sy8Eoz...
#
#        commenter_channel_id commenter_channel_display_name  \
# 0  UCeWYnjrT3_rDlA8ocXsYUSA                    PetClip Joe
# 1  UCNwV1VD6TAz5anU91y3vTjw                   Indy Visible
# 2  UCgvLGMHYXTWsqJH8p8NqBIQ              Life Time Fitness
# 3  UCT5oH7xY930PZlCZGIYGPSg                Søcial_Pressure
# 4  UCL1FJuJ8Sy8EozB1Q1e-YuA                         Daniel
#
#                    comment_id  comment_like_count  comment_publish_date  \
# 0  UgyD4ISCdZQYOsBqxFJ4AaABAg                 0.0          1.699049e+09
# 1  Ugx9YYg2b0Hsa2zKPpF4AaABAg                 0.0          1.698894e+09
# 2  UgzLxCfr55FLPvTrJl94AaABAg                 0.0          1.698750e+09
# 3  Ugx13DzUKxnC9QqaMZV4AaABAg                 0.0          1.698709e+09
# 4  Ugy2QlOcLqXWcT4XamB4AaABAg                 0.0          1.698698e+09
#
#                                                 text commenter_rating  \
# 0  Term Limited for all Politicians and NOT only ...             none
# 1  These gold bars are simply being accused of lo...             none
# 2                😂😂😂😂😂😂😅😅😅😅 thieves knew it coming 😅             none
# 3  Uncle Sam is cool with blatant bribery in a fo...             none
# 4     Isnt this Lobbying? I don't see anything wrong             none
#
#    comment_parent_id             collection_date  reply_count  day  \
# 0                NaN  2023-11-28 12:50:42.731374          0.0    1
# 1                NaN  2023-11-28 12:50:42.731374          0.0    1
# 2                NaN  2023-11-28 12:50:42.731374          0.0    1
# 3                NaN  2023-11-28 12:50:42.731374          0.0    1
# 4                NaN  2023-11-28 12:50:42.731374          0.0    1
#
#   day_published         publish_date
# 0    2023-09-22  2023-11-03 22:03:29
# 1    2023-09-22  2023-11-02 02:53:23
# 2    2023-09-22  2023-10-31 10:53:08
# 3    2023-09-22  2023-10-30 23:39:20
# 4    2023-09-22  2023-10-30 20:34:34

# %%
subset = sentiment_menendez.head(50)

# %%
subset
# Out:
#        video_id                              commenter_channel_url  \
# 0   u1l2dbqP7oA  http://www.youtube.com/channel/UCeWYnjrT3_rDlA...
# 1   u1l2dbqP7oA  http://www.youtube.com/channel/UCNwV1VD6TAz5an...
# 2   u1l2dbqP7oA  http://www.youtube.com/channel/UCgvLGMHYXTWsqJ...
# 3   u1l2dbqP7oA  http://www.youtube.com/channel/UCT5oH7xY930PZl...
# 4   u1l2dbqP7oA  http://www.youtube.com/channel/UCL1FJuJ8Sy8Eoz...
# 5   u1l2dbqP7oA  http://www.youtube.com/channel/UCzp9KoPem6ZfXj...
# 6   u1l2dbqP7oA  http://www.youtube.com/channel/UC9gSrF6xdS6LEL...
# 42  u1l2dbqP7oA  http://www.youtube.com/channel/UCbHj8kbq1O_nlL...
# 43  u1l2dbqP7oA  http://www.youtube.com/channel/UCyjX4y_V9-G-75...
# 44  u1l2dbqP7oA  http://www.youtube.com/channel/UC8gczfGeVHEZi9...
# 45  u1l2dbqP7oA  http://www.youtube.com/channel/UCoe_ju3bDpN5KA...
# 46  u1l2dbqP7oA  http://www.youtube.com/channel/UCTJGy1sXwr18Ko...
# 47  u1l2dbqP7oA  http://www.youtube.com/channel/UCj77Kp7GgL_QPt...
# 48  u1l2dbqP7oA  http://www.youtube.com/channel/UC7xBJoqx69U7cp...
# 49  u1l2dbqP7oA  http://www.youtube.com/channel/UCHNNzxliZEf7OR...
#
#         commenter_channel_id commenter_channel_display_name  \
# 0   UCeWYnjrT3_rDlA8ocXsYUSA                    PetClip Joe
# 1   UCNwV1VD6TAz5anU91y3vTjw                   Indy Visible
# 2   UCgvLGMHYXTWsqJH8p8NqBIQ              Life Time Fitness
# 3   UCT5oH7xY930PZlCZGIYGPSg                Søcial_Pressure
# 4   UCL1FJuJ8Sy8EozB1Q1e-YuA                         Daniel
# 5   UCzp9KoPem6ZfXjEXx1KPZaw                             RR
# 6   UC9gSrF6xdS6LELJox-5A71Q                            S P
# 7   UC9gSrF6xdS6LELJox-5A71Q                            S P
# 8   UC3VqkHyyLmtw3Obhrlou4bw               Raymond Cascella
# 9   UCBKI_A4I5_Uijaj6oK3BwXQ                  SOUTHERN LIFE
# 10  UC9V5rRicaHUovxY-sP59zGg                     Heinz Heko
# 11  UCd3Bw2lrYzF9KD1hHix0uyw                    Garry Jones
# 12  UCKx6937PEHhMZ72rtAZcM-Q                        Reubhén
# 13  UC40UMuEmvwv25tUjYH_7YPQ               J.Mendez Del Rio
# 14  UC4URvD7yJdgyx07qKYxALxg                    Kevin Clark
# 15  UCEf0091I8P78MCCZVViHxRA           constantino valverde
# 16  UCynDRKTOVRQZ2j3_FH6L6nA                 Manoj Parajuli
# 17  UClRQidcm1k6CPfhEa-woJsg                            S h
# 18  UC9sTuRUyXUpTrK5BEF5_51A                        D STONE
# 19  UC4bMvSxLIqvlwBn9j3amaBw                     Armyan1988
# 20  UC0uiQj1hGME8aFQWZVuytIw                   david garton
# 21  UCKBsRGAOB0ggRJMwdlLePLw                     Fh Clappen
# 22  UCxIg7dS2tOsBZp12G7FRGwg                    M. Aurelius
# 23  UCH4VdxIekLGEH1NxIjPe1WA                    Jimmy Timmy
# 24  UCb9xSHDLynG50JJ2Dx4fVOw                          Power
# 25  UCaGFVEY-Bo-INxpv9f04jyw               Fisherman Ape Jv
# 26  UC011zuDwYTAsrD65te6tWEg                  chungking1974
# 27  UCia3f1nCOLzzU77WD1Bxi_w                AMG Electronics
# 28  UC_ewE-15GNXMB_2A5yY1F6A                  scott mullins
# 29  UCbhgGzZbyyNIXzOoQuiyokw                     jean cadet
# 30  UCbhgGzZbyyNIXzOoQuiyokw                     jean cadet
# 31  UCbhgGzZbyyNIXzOoQuiyokw                     jean cadet
# 32  UC0XOPpJuFprjS8pAwKySKjg             Rightwingtrash Rus
# 33  UChMlfN1jpa-NyXX6-ktdzFg                         Budz.e
# 34  UCSAHA3U39kzT6YbHqwcqwjA                    Erkan sivas
# 35  UCgpq8yK1qytCfbd8UQ5vzbA                Mirza Musanovic
# 36  UCc5wlDONJJuQpFxdsW-Iv6A                Voice of Reason
# 37  UCy9JNmBwNlLpAwLR4kACIow                  kameron kleut
# 38  UCMSp7742hjyP63-_P10r1nQ               steve yavuzcehre
# 39  UC2dXezuO36ioCq7Im9hFWUQ                       Poutinez
# 40  UCq8_pla5m06rPYCnntE0RNg                 Miguel A Matos
# 41  UCh2DUG2BZkdzHUD0QCg1uZQ                   watercrest69
# 42  UCbHj8kbq1O_nlLUMdCKmqUw                     Gully Bull
# 43  UCyjX4y_V9-G-75xrQtiUCcw                      swiss9495
# 44  UC8gczfGeVHEZi9FraQb9Rmg                    Anas Afandi
# 45  UCoe_ju3bDpN5KAi1BXKsPRA               DRACO FURY RX 13
# 46  UCTJGy1sXwr18Ko2iRxNQcDA                             me
# 47  UCj77Kp7GgL_QPta4LXL5sTg                  Kenneth Heron
# 48  UC7xBJoqx69U7cpXHp4uVRxQ                     blount out
# 49  UCHNNzxliZEf7ORE0t7AQJTA                Just'AMessenger
#
#                     comment_id  comment_like_count  comment_publish_date  \
# 0   UgyD4ISCdZQYOsBqxFJ4AaABAg                 0.0          1.699049e+09
# 1   Ugx9YYg2b0Hsa2zKPpF4AaABAg                 0.0          1.698894e+09
# 2   UgzLxCfr55FLPvTrJl94AaABAg                 0.0          1.698750e+09
# 3   Ugx13DzUKxnC9QqaMZV4AaABAg                 0.0          1.698709e+09
# 4   Ugy2QlOcLqXWcT4XamB4AaABAg                 0.0          1.698698e+09
# 5   UgxqNNw8Pl5tdWx6EZp4AaABAg                 0.0          1.698697e+09
# 6   UgxA28tzqxQVy_GAvjJ4AaABAg                 0.0          1.698697e+09
# 7   Ugyrk-SBbPs6EbRimIl4AaABAg                 0.0          1.698696e+09
# 8   Ugxt8i9LqMW83W1HkUt4AaABAg                 0.0          1.698696e+09
# 9   UgwGaA5JDEu7v7z0Vt94AaABAg                 2.0          1.698696e+09
# 10  Ugx4Kipi-9Lx0t245fF4AaABAg                 0.0          1.698647e+09
# 11  Ugyy7a9Mx2GlM77A_g14AaABAg                 0.0          1.698646e+09
# 12  UgzpkdmQHn3fiTBXYqN4AaABAg                 0.0          1.698645e+09
# 13  UgwiFGFSYr9DRXXiaLh4AaABAg                 0.0          1.698643e+09
# 14  Ugwg7z_Tl4aoxfdTx754AaABAg                 0.0          1.698639e+09
# 15  UgxDu4QXgV6vfxLoW0V4AaABAg                 0.0          1.698625e+09
# 16  UgxSmM8VS8g7vsSVwDt4AaABAg                 0.0          1.698623e+09
# 17  UgxgegYhcvMml2ffQ2l4AaABAg                 0.0          1.698608e+09
# 18  UgxHtHqvbd-fatPQnyR4AaABAg                 0.0          1.698604e+09
# 19  UgzrgTiyULPuVrKF1Ah4AaABAg                 0.0          1.698573e+09
# 20  UgxcuIvSI0Ffrsmjo4l4AaABAg                 0.0          1.698562e+09
# 21  Ugxr_-cwPr4xuASzQb94AaABAg                 0.0          1.698556e+09
# 22  Ugzifqj2xRm0GY8Af9p4AaABAg                 1.0          1.698552e+09
# 23  Ugy0I9JzgCmzFBbVlY94AaABAg                 0.0          1.698543e+09
# 24  UgzTVYXjNw4wOmT1th54AaABAg                 0.0          1.698541e+09
# 25  UgyazDHhy4kRZUGaFCF4AaABAg                 0.0          1.698540e+09
# 26  UgwZJVPfRdABCXCWt-F4AaABAg                 0.0          1.698536e+09
# 27  Ugyx8KH79QXLmn7S3wd4AaABAg                 0.0          1.698527e+09
# 28  Ugzl-5zH7zyISbG9_8p4AaABAg                 0.0          1.698520e+09
# 29  Ugz5-avPxRO_BGJeMn14AaABAg                 0.0          1.698515e+09
# 30  Ugxdl1UWK6ichbWEBpp4AaABAg                 0.0          1.698515e+09
# 31  UgzTRYY7gS-lJNN8jzV4AaABAg                 0.0          1.698515e+09
# 32  UgwF6qTnCEqJ0Jo9AcN4AaABAg                 0.0          1.698512e+09
# 33  Ugz-IL_r4bnsbMsl8x54AaABAg                 0.0          1.698512e+09
# 34  UgyapCrAtL8KxqegHiB4AaABAg                 0.0          1.698493e+09
# 35  UgwKCHTHJN7Rd0_j43J4AaABAg                 0.0          1.698487e+09
# 36  UgxTjS2hiYGZzXoTHS14AaABAg                 0.0          1.698482e+09
# 37  Ugze99S7MUnAEjvysfx4AaABAg                 0.0          1.698478e+09
# 38  UgyQCnNMPVFTldq7IQN4AaABAg                 0.0          1.698472e+09
# 39  UgzuUIGFvKOZ3s8Xo954AaABAg                 0.0          1.698471e+09
# 40  UgyI_SJMm2b69G7SEyh4AaABAg                 0.0          1.698467e+09
# 41  UgzjjpqsT9stkdhyIt94AaABAg                 0.0          1.698466e+09
# 42  UgwLAt1o6LFme4g8DR54AaABAg                 0.0          1.698444e+09
# 43  UgxEOWENWR3mgzpyOBB4AaABAg                 0.0          1.698440e+09
# 44  UgzrkozESVt5ynGqLpN4AaABAg                 0.0          1.698438e+09
# 45  Ugxh_Rb5paKuMhmxrv54AaABAg                 0.0          1.698437e+09
# 46  UgxXKvprV-dFhDnpFdp4AaABAg                 0.0          1.698431e+09
# 47  UgwU7oJglq6fEZRn6-l4AaABAg                 0.0          1.698425e+09
# 48  UgyXznoZw2BFsZguQad4AaABAg                 0.0          1.698424e+09
# 49  Ugx1YO86MLJIIE2C3El4AaABAg                 0.0          1.698423e+09
#
#                                                  text commenter_rating  \
# 0   Term Limited for all Politicians and NOT only ...             none
# 1   These gold bars are simply being accused of lo...             none
# 2                 😂😂😂😂😂😂😅😅😅😅 thieves knew it coming 😅             none
# 3   Uncle Sam is cool with blatant bribery in a fo...             none
# 4      Isnt this Lobbying? I don't see anything wrong             none
# 5   Where was the accountability how can this keep...             none
# 6                  What about BIDEN AND HUNTER BIDEN?             none
# 7                   What about BARRACK HUSSAIN OBAMA?             none
# 8                       When are you indicting Biden?             none
# 9                   so basically he was a politician?             none
# 10                              Of course a democrat!             none
# 11         Had more gold stashed than a Leprechaun!😂😂             none
# 12                          Put this MDF in the jail.             none
# 13  This is why there should be term LIMITS in all...             none
# 31    2023-09-22  2023-10-28 17:41:16
# 32    2023-09-22  2023-10-28 16:55:27
# 33    2023-09-22  2023-10-28 16:54:34
# 34    2023-09-22  2023-10-28 11:35:08
# 35    2023-09-22  2023-10-28 09:51:13
# 36    2023-09-22  2023-10-28 08:31:04
# 37    2023-09-22  2023-10-28 07:23:34
# 38    2023-09-22  2023-10-28 05:51:33
# 39    2023-09-22  2023-10-28 05:35:20
# 40    2023-09-22  2023-10-28 04:23:34
# 41    2023-09-22  2023-10-28 04:13:39
# 42    2023-09-22  2023-10-27 22:06:58
# 43    2023-09-22  2023-10-27 20:57:39
# 44    2023-09-22  2023-10-27 20:27:28
# 45    2023-09-22  2023-10-27 20:08:29
# 46    2023-09-22  2023-10-27 18:21:52
# 47    2023-09-22  2023-10-27 16:51:24
# 48    2023-09-22  2023-10-27 16:21:22
# 49    2023-09-22  2023-10-27 16:06:40

# %%
# hugging face
from transformers import pipeline
sentiment_analyzer = pipeline("sentiment-analysis", model="lxyuan/distilbert-base-multilingual-cased-sentiments-student", return_all_scores=True)
resultado = subset['text'].apply(lambda x: sentiment_analyzer(x))
print(resultado)
# Out:
# C:\Users\gabos\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\text_classification.py:105: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# 0     [[{'label': 'positive', 'score': 0.30827081203...
# 1     [[{'label': 'positive', 'score': 0.08846271038...
# 2     [[{'label': 'positive', 'score': 0.43397974967...
# 3     [[{'label': 'positive', 'score': 0.19576412439...
# 4     [[{'label': 'positive', 'score': 0.20417511463...
# 5     [[{'label': 'positive', 'score': 0.21955977380...
# 6     [[{'label': 'positive', 'score': 0.33421018719...
# 7     [[{'label': 'positive', 'score': 0.31697085499...
# 8     [[{'label': 'positive', 'score': 0.21390336751...
# 9     [[{'label': 'positive', 'score': 0.27591976523...
# 10    [[{'label': 'positive', 'score': 0.55834084749...
# 11    [[{'label': 'positive', 'score': 0.37411975860...
# 12    [[{'label': 'positive', 'score': 0.22105154395...
# 13    [[{'label': 'positive', 'score': 0.25587776303...
# 14    [[{'label': 'positive', 'score': 0.22808820009...
# 15    [[{'label': 'positive', 'score': 0.06980435550...
# 16    [[{'label': 'positive', 'score': 0.12498103827...
# 17    [[{'label': 'positive', 'score': 0.34000715613...
# 18    [[{'label': 'positive', 'score': 0.08546965569...
# 19    [[{'label': 'positive', 'score': 0.41630655527...
# 20    [[{'label': 'positive', 'score': 0.16896210610...
# 21    [[{'label': 'positive', 'score': 0.13960592448...
# 22    [[{'label': 'positive', 'score': 0.16075392067...
# 23    [[{'label': 'positive', 'score': 0.26567530632...
# 24    [[{'label': 'positive', 'score': 0.08920840919...
# 25    [[{'label': 'positive', 'score': 0.20282925665...
# 26    [[{'label': 'positive', 'score': 0.26004561781...
# 27    [[{'label': 'positive', 'score': 0.11594330519...
# 28    [[{'label': 'positive', 'score': 0.29433971643...
# 29    [[{'label': 'positive', 'score': 0.02915553748...
# 30    [[{'label': 'positive', 'score': 0.14412136375...
# 31    [[{'label': 'positive', 'score': 0.22950743138...
# 32    [[{'label': 'positive', 'score': 0.34989178180...
# 33    [[{'label': 'positive', 'score': 0.25943607091...
# 34    [[{'label': 'positive', 'score': 0.23746551573...
# 35    [[{'label': 'positive', 'score': 0.21899996697...
# 36    [[{'label': 'positive', 'score': 0.78334653377...
# 37    [[{'label': 'positive', 'score': 0.14495176076...
# 38    [[{'label': 'positive', 'score': 0.07144614309...
# 39    [[{'label': 'positive', 'score': 0.46796160936...
# 40    [[{'label': 'positive', 'score': 0.22607891261...
# 41    [[{'label': 'positive', 'score': 0.03525626659...
# 42    [[{'label': 'positive', 'score': 0.69569456577...
# 43    [[{'label': 'positive', 'score': 0.05546838045...
# 44    [[{'label': 'positive', 'score': 0.13468486070...
# 45    [[{'label': 'positive', 'score': 0.24834428727...
# 46    [[{'label': 'positive', 'score': 0.21559837460...
# 47    [[{'label': 'positive', 'score': 0.08569998294...
# 48    [[{'label': 'positive', 'score': 0.65141642093...
# 49    [[{'label': 'positive', 'score': 0.16130602359...
# Name: text, dtype: object

# %%
resultado.iloc[0]
# Out:
# [[{'label': 'positive', 'score': 0.30827081203460693},
#   {'label': 'neutral', 'score': 0.20612406730651855},
#   {'label': 'negative', 'score': 0.4856051802635193}]]

# %%
sentiment_analyzer = pipeline("sentiment-analysis", model="lxyuan/distilbert-base-multilingual-cased-sentiments-student", return_all_scores=True)
subset['sentiment'] = subset['text'].apply(lambda x: sentiment_analyzer(x))
# Out:
# C:\Users\gabos\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\text_classification.py:105: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# C:\Users\gabos\AppData\Local\Temp\ipykernel_6984\130276534.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['sentiment'] = subset['text'].apply(lambda x: sentiment_analyzer(x))

# %%
# Function to extract sentiment scores
def get_sentiment_score(sentiment_list, target_label):
    for sentiment_dict in sentiment_list:
        if sentiment_dict['label'] == target_label:
            return sentiment_dict['score']
    return None

# Create separate columns for 'positive', 'neutral', and 'negative'
subset['positive_score'] = subset['sentiment'].apply(lambda x: get_sentiment_score(x, 'positive'))
subset['neutral_score'] = subset['sentiment'].apply(lambda x: get_sentiment_score(x, 'neutral'))
subset['negative_score'] = subset['sentiment'].apply(lambda x: get_sentiment_score(x, 'negative'))

# Print the modified DataFrame
subset.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 9
#       6     return None
#       8 # Create separate columns for 'positive', 'neutral', and 'negative'
# ----> 9 subset['positive_score'] = subset['sentiment'].apply(lambda x: get_sentiment_score(x, 'positive'))
#      10 subset['neutral_score'] = subset['sentiment'].apply(lambda x: get_sentiment_score(x, 'neutral'))
#      11 subset['negative_score'] = subset['sentiment'].apply(lambda x: get_sentiment_score(x, 'negative'))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[57], line 9, in <lambda>(x)
#       6     return None
#       8 # Create separate columns for 'positive', 'neutral', and 'negative'
# ----> 9 subset['positive_score'] = subset['sentiment'].apply(lambda x: get_sentiment_score(x, 'positive'))
#      10 subset['neutral_score'] = subset['sentiment'].apply(lambda x: get_sentiment_score(x, 'neutral'))
#      11 subset['negative_score'] = subset['sentiment'].apply(lambda x: get_sentiment_score(x, 'negative'))
#
# Cell In[57], line 4, in get_sentiment_score(sentiment_list, target_label)
#       2 def get_sentiment_score(sentiment_list, target_label):
#       3     for sentiment_dict in sentiment_list:
# ----> 4         if sentiment_dict['label'] == target_label:
#       5             return sentiment_dict['score']
#       6     return None
#
# TypeError: list indices must be integers or slices, not str

# %%
subset.head()
# Out:
#       video_id                              commenter_channel_url  \
# 0  u1l2dbqP7oA  http://www.youtube.com/channel/UCeWYnjrT3_rDlA...
# 1  u1l2dbqP7oA  http://www.youtube.com/channel/UCNwV1VD6TAz5an...
# 2  u1l2dbqP7oA  http://www.youtube.com/channel/UCgvLGMHYXTWsqJ...
# 3  u1l2dbqP7oA  http://www.youtube.com/channel/UCT5oH7xY930PZl...
# 4  u1l2dbqP7oA  http://www.youtube.com/channel/UCL1FJuJ8Sy8Eoz...
#
#        commenter_channel_id commenter_channel_display_name  \
# 0  UCeWYnjrT3_rDlA8ocXsYUSA                    PetClip Joe
# 1  UCNwV1VD6TAz5anU91y3vTjw                   Indy Visible
# 2  UCgvLGMHYXTWsqJH8p8NqBIQ              Life Time Fitness
# 3  UCT5oH7xY930PZlCZGIYGPSg                Søcial_Pressure
# 4  UCL1FJuJ8Sy8EozB1Q1e-YuA                         Daniel
#
#                    comment_id  comment_like_count  comment_publish_date  \
# 0  UgyD4ISCdZQYOsBqxFJ4AaABAg                 0.0          1.699049e+09
# 1  Ugx9YYg2b0Hsa2zKPpF4AaABAg                 0.0          1.698894e+09
# 2  UgzLxCfr55FLPvTrJl94AaABAg                 0.0          1.698750e+09
# 3  Ugx13DzUKxnC9QqaMZV4AaABAg                 0.0          1.698709e+09
# 4  Ugy2QlOcLqXWcT4XamB4AaABAg                 0.0          1.698698e+09
#
#                                                 text commenter_rating  \
# 0  Term Limited for all Politicians and NOT only ...             none
# 1  These gold bars are simply being accused of lo...             none
# 2                😂😂😂😂😂😂😅😅😅😅 thieves knew it coming 😅             none
# 3  Uncle Sam is cool with blatant bribery in a fo...             none
# 4     Isnt this Lobbying? I don't see anything wrong             none
#
#    comment_parent_id             collection_date  reply_count  day  \
# 0                NaN  2023-11-28 12:50:42.731374          0.0    1
# 1                NaN  2023-11-28 12:50:42.731374          0.0    1
# 2                NaN  2023-11-28 12:50:42.731374          0.0    1
# 3                NaN  2023-11-28 12:50:42.731374          0.0    1
# 4                NaN  2023-11-28 12:50:42.731374          0.0    1
#
#   day_published         publish_date  \
# 0    2023-09-22  2023-11-03 22:03:29
# 1    2023-09-22  2023-11-02 02:53:23
# 2    2023-09-22  2023-10-31 10:53:08
# 3    2023-09-22  2023-10-30 23:39:20
# 4    2023-09-22  2023-10-30 20:34:34
#
#                                            sentiment
# 0  [[{'label': 'positive', 'score': 0.30827081203...
# 1  [[{'label': 'positive', 'score': 0.08846271038...
# 2  [[{'label': 'positive', 'score': 0.43397974967...
# 3  [[{'label': 'positive', 'score': 0.19576412439...
# 4  [[{'label': 'positive', 'score': 0.20417511463...

# %%
# Function to extract sentiment scores
def get_sentiment_score(sentiment_list, target_label):
    for sentiment_dict in sentiment_list[0]:  # Access the first (and only) element in the list
        if sentiment_dict['label'] == target_label:
            return sentiment_dict['score']
    return None

# Create separate columns for 'positive', 'neutral', and 'negative'
subset['positive_score'] = subset['sentiment'].apply(lambda x: get_sentiment_score(x, 'positive'))
subset['neutral_score'] = subset['sentiment'].apply(lambda x: get_sentiment_score(x, 'neutral'))
subset['negative_score'] = subset['sentiment'].apply(lambda x: get_sentiment_score(x, 'negative'))

# Print the modified DataFrame
subset.tail(10)
# Out:
# C:\Users\gabos\AppData\Local\Temp\ipykernel_6984\55377359.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['positive_score'] = subset['sentiment'].apply(lambda x: get_sentiment_score(x, 'positive'))
# C:\Users\gabos\AppData\Local\Temp\ipykernel_6984\55377359.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['neutral_score'] = subset['sentiment'].apply(lambda x: get_sentiment_score(x, 'neutral'))
# C:\Users\gabos\AppData\Local\Temp\ipykernel_6984\55377359.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['negative_score'] = subset['sentiment'].apply(lambda x: get_sentiment_score(x, 'negative'))
#        video_id                              commenter_channel_url  \
# 40  u1l2dbqP7oA  http://www.youtube.com/channel/UCq8_pla5m06rPY...
# 41  u1l2dbqP7oA  http://www.youtube.com/channel/UCh2DUG2BZkdzHU...
# 42  u1l2dbqP7oA  http://www.youtube.com/channel/UCbHj8kbq1O_nlL...
# 43  u1l2dbqP7oA  http://www.youtube.com/channel/UCyjX4y_V9-G-75...
# 44  u1l2dbqP7oA  http://www.youtube.com/channel/UC8gczfGeVHEZi9...
# 45  u1l2dbqP7oA  http://www.youtube.com/channel/UCoe_ju3bDpN5KA...
# 46  u1l2dbqP7oA  http://www.youtube.com/channel/UCTJGy1sXwr18Ko...
# 47  u1l2dbqP7oA  http://www.youtube.com/channel/UCj77Kp7GgL_QPt...
# 48  u1l2dbqP7oA  http://www.youtube.com/channel/UC7xBJoqx69U7cp...
# 49  u1l2dbqP7oA  http://www.youtube.com/channel/UCHNNzxliZEf7OR...
#
#         commenter_channel_id commenter_channel_display_name  \
# 40  UCq8_pla5m06rPYCnntE0RNg                 Miguel A Matos
# 41  UCh2DUG2BZkdzHUD0QCg1uZQ                   watercrest69
# 42  UCbHj8kbq1O_nlLUMdCKmqUw                     Gully Bull
# 43  UCyjX4y_V9-G-75xrQtiUCcw                      swiss9495
# 44  UC8gczfGeVHEZi9FraQb9Rmg                    Anas Afandi
# 45  UCoe_ju3bDpN5KAi1BXKsPRA               DRACO FURY RX 13
# 46  UCTJGy1sXwr18Ko2iRxNQcDA                             me
# 47  UCj77Kp7GgL_QPta4LXL5sTg                  Kenneth Heron
# 48  UC7xBJoqx69U7cpXHp4uVRxQ                     blount out
# 49  UCHNNzxliZEf7ORE0t7AQJTA                Just'AMessenger
#
#                     comment_id  comment_like_count  comment_publish_date  \
# 40  UgyI_SJMm2b69G7SEyh4AaABAg                 0.0          1.698467e+09
# 41  UgzjjpqsT9stkdhyIt94AaABAg                 0.0          1.698466e+09
# 42  UgwLAt1o6LFme4g8DR54AaABAg                 0.0          1.698444e+09
# 43  UgxEOWENWR3mgzpyOBB4AaABAg                 0.0          1.698440e+09
# 44  UgzrkozESVt5ynGqLpN4AaABAg                 0.0          1.698438e+09
# 45  Ugxh_Rb5paKuMhmxrv54AaABAg                 0.0          1.698437e+09
# 46  UgxXKvprV-dFhDnpFdp4AaABAg                 0.0          1.698431e+09
# 47  UgwU7oJglq6fEZRn6-l4AaABAg                 0.0          1.698425e+09
# 48  UgyXznoZw2BFsZguQad4AaABAg                 0.0          1.698424e+09
# 49  Ugx1YO86MLJIIE2C3El4AaABAg                 0.0          1.698423e+09
#
#                                                  text commenter_rating  \
# 40  Meanwhile him and his democrat friends call Do...             none
# 41  This senator’s corruption is peanuts compared ...             none
# 42                           Nazi.gold.\nZionistgold.             none
# 43  What's wrong with that. That happens in Washin...             none
# 44  look up all the president and senates and the ...             none
# 45  It's Illegal To Have Gold In yo House?\n*Uh Oo...             none
# 46  What about hunter biden and his connection to ...             none
# 47  oh please he's a low lying fruit. There's more...             none
# 48            nothing wrong with having a lot of gold             none
# 49  Money is all game thats why theres greed and c...             none
#
#     comment_parent_id             collection_date  reply_count  day  \
# 40                NaN  2023-11-28 12:50:42.737918          0.0    1
# 41                NaN  2023-11-28 12:50:42.737918          0.0    1
# 42                NaN  2023-11-28 12:50:42.737918          0.0    1
# 43                NaN  2023-11-28 12:50:42.737918          0.0    1
# 44                NaN  2023-11-28 12:50:42.737918          0.0    1
# 45                NaN  2023-11-28 12:50:42.737918          0.0    1
# 46                NaN  2023-11-28 12:50:42.737918          0.0    1
# 47                NaN  2023-11-28 12:50:42.737918          0.0    1
# 48                NaN  2023-11-28 12:50:42.737918          0.0    1
# 49                NaN  2023-11-28 12:50:42.737918          0.0    1
#
#    day_published         publish_date  \
# 40    2023-09-22  2023-10-28 04:23:34
# 41    2023-09-22  2023-10-28 04:13:39
# 42    2023-09-22  2023-10-27 22:06:58
# 43    2023-09-22  2023-10-27 20:57:39
# 44    2023-09-22  2023-10-27 20:27:28
# 45    2023-09-22  2023-10-27 20:08:29
# 46    2023-09-22  2023-10-27 18:21:52
# 47    2023-09-22  2023-10-27 16:51:24
# 48    2023-09-22  2023-10-27 16:21:22
# 49    2023-09-22  2023-10-27 16:06:40
#
#                                             sentiment  positive_score  \
# 40  [[{'label': 'positive', 'score': 0.22607891261...        0.226079
# 41  [[{'label': 'positive', 'score': 0.03525626659...        0.035256
# 42  [[{'label': 'positive', 'score': 0.69569456577...        0.695695
# 43  [[{'label': 'positive', 'score': 0.05546838045...        0.055468
# 44  [[{'label': 'positive', 'score': 0.13468486070...        0.134685
# 45  [[{'label': 'positive', 'score': 0.24834428727...        0.248344
# 46  [[{'label': 'positive', 'score': 0.21559837460...        0.215598
# 47  [[{'label': 'positive', 'score': 0.08569998294...        0.085700
# 48  [[{'label': 'positive', 'score': 0.65141642093...        0.651416
# 49  [[{'label': 'positive', 'score': 0.16130602359...        0.161306
#
#     neutral_score  negative_score
# 40       0.131461        0.642460
# 41       0.037021        0.927723
# 42       0.073351        0.230954
# 43       0.097631        0.846900
# 44       0.098222        0.767094
# 45       0.196302        0.555353
# 46       0.231018        0.553384
# 47       0.093202        0.821098
# 48       0.281213        0.067370
# 49       0.108462        0.730232

# %%
sentiment_analyzer = pipeline("sentiment-analysis", model="lxyuan/distilbert-base-multilingual-cased-sentiments-student", return_all_scores=True)
sentiment_menendez['sentiment'] = sentiment_menendez['text'].apply(lambda x: sentiment_analyzer(x))
# Out:
# C:\Users\gabos\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\text_classification.py:105: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# Token indices sequence length is longer than the specified maximum sequence length for this model (592 > 512). Running this sequence through the model will result in indexing errors
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[68], line 2
#       1 sentiment_analyzer = pipeline("sentiment-analysis", model="lxyuan/distilbert-base-multilingual-cased-sentiments-student", return_all_scores=True)
# ----> 2 sentiment_menendez['sentiment'] = sentiment_menendez['text'].apply(lambda x: sentiment_analyzer(x))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[68], line 2, in <lambda>(x)
#       1 sentiment_analyzer = pipeline("sentiment-analysis", model="lxyuan/distilbert-base-multilingual-cased-sentiments-student", return_all_scores=True)
# ----> 2 sentiment_menendez['sentiment'] = sentiment_menendez['text'].apply(lambda x: sentiment_analyzer(x))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\text_classification.py:156, in TextClassificationPipeline.__call__(self, *args, **kwargs)
#     122 def __call__(self, *args, **kwargs):
#     123     """
#     124     Classify the text(s) given as inputs.
#     125
#    (...)
#     154         If `top_k` is used, one such dictionary is returned per label.
#     155     """
# --> 156     result = super().__call__(*args, **kwargs)
#     157     # TODO try and retrieve it in a nicer way from _sanitize_parameters.
#     158     _legacy = "top_k" not in kwargs
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\base.py:1140, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1132     return next(
#    1133         iter(
#    1134             self.get_iterator(
#    (...)
#    1137         )
#    1138     )
#    1139 else:
# -> 1140     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\base.py:1147, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1145 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1146     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1147     model_outputs = self.forward(model_inputs, **forward_params)
#    1148     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1149     return outputs
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\base.py:1046, in Pipeline.forward(self, model_inputs, **forward_params)
#    1044     with inference_context():
#    1045         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1046         model_outputs = self._forward(model_inputs, **forward_params)
#    1047         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1048 else:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\text_classification.py:187, in TextClassificationPipeline._forward(self, model_inputs)
#     185 if "use_cache" in inspect.signature(model_forward).parameters.keys():
#     186     model_inputs["use_cache"] = False
# --> 187 return self.model(**model_inputs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:779, in DistilBertForSequenceClassification.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#     771 r"""
#     772 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#     773     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#     774     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#     775     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#     776 """
#     777 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# --> 779 distilbert_output = self.distilbert(
#     780     input_ids=input_ids,
#     781     attention_mask=attention_mask,
#     782     head_mask=head_mask,
#     783     inputs_embeds=inputs_embeds,
#     784     output_attentions=output_attentions,
#     785     output_hidden_states=output_hidden_states,
#     786     return_dict=return_dict,
#     787 )
#     788 hidden_state = distilbert_output[0]  # (bs, seq_len, dim)
#     789 pooled_output = hidden_state[:, 0]  # (bs, dim)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:597, in DistilBertModel.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     594 # Prepare head mask if needed
#     595 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# --> 597 embeddings = self.embeddings(input_ids, inputs_embeds)  # (bs, seq_length, dim)
#     599 return self.transformer(
#     600     x=embeddings,
#     601     attn_mask=attention_mask,
#    (...)
#     605     return_dict=return_dict,
#     606 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:135, in Embeddings.forward(self, input_ids, input_embeds)
#     131     position_ids = position_ids.unsqueeze(0).expand_as(input_ids)  # (bs, max_seq_length)
#     133 position_embeddings = self.position_embeddings(position_ids)  # (bs, max_seq_length, dim)
# --> 135 embeddings = input_embeds + position_embeddings  # (bs, max_seq_length, dim)
#     136 embeddings = self.LayerNorm(embeddings)  # (bs, max_seq_length, dim)
#     137 embeddings = self.dropout(embeddings)  # (bs, max_seq_length, dim)
#
# RuntimeError: The size of tensor a (592) must match the size of tensor b (512) at non-singleton dimension 1

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("lxyuan/distilbert-base-multilingual-cased-sentiments-student")

# Get the text from the first row of the 'text' column
first_row_text = sentiment_menendez['text'].iloc[0]

# Tokenize the text and count the number of tokens
tokenized_text = tokenizer(first_row_text)
num_tokens = len(tokenized_text['input_ids'])

# Print the number of tokens
print(f"Number of tokens in the first row: {num_tokens}")
# Out:
# Number of tokens in the first row: 23

# %%
sentiment_menendez['text'].iloc[0]
# Out:
# 'Term Limited for all Politicians and NOT only for the President!!!!!'

# %%
def truncate_text(text):
    return text[:512]

# Apply the truncation function to the 'text' column
sentiment_menendez['text'] = sentiment_menendez['text'].apply(truncate_text)

sentiment_analyzer = pipeline("sentiment-analysis", model="lxyuan/distilbert-base-multilingual-cased-sentiments-student", return_all_scores=True)
sentiment_menendez['sentiment'] = sentiment_menendez['text'].apply(lambda x: sentiment_analyzer(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 5
#       2     return text[:512]
#       4 # Apply the truncation function to the 'text' column
# ----> 5 sentiment_menendez['text'] = sentiment_menendez['text'].apply(truncate_text)
#       7 sentiment_analyzer = pipeline("sentiment-analysis", model="lxyuan/distilbert-base-multilingual-cased-sentiments-student", return_all_scores=True)
#       8 sentiment_menendez['sentiment'] = sentiment_menendez['text'].apply(lambda x: sentiment_analyzer(x))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[73], line 2, in truncate_text(text)
#       1 def truncate_text(text):
# ----> 2     return text[:512]
#
# TypeError: 'float' object is not subscriptable

# %%
# Function to truncate text to the first 512 tokens
def truncate_text(text):
    if isinstance(text, str):
        return text[:512]
    else:
        return text

# Apply the truncation function to the 'text' column
sentiment_menendez['text'] = sentiment_menendez['text'].apply(truncate_text)

# Filter out NaN values before applying sentiment analysis
non_nan_rows = sentiment_menendez.dropna(subset=['text'])

# Initialize the sentiment analyzer
sentiment_analyzer = pipeline("sentiment-analysis", model="lxyuan/distilbert-base-multilingual-cased-sentiments-student", return_all_scores=True)

# Apply sentiment analysis to the filtered DataFrame
non_nan_rows['sentiment'] = non_nan_rows['text'].apply(lambda x: sentiment_analyzer(x))

# Print the modified DataFrame
print(non_nan_rows)
# Out:
# C:\Users\gabos\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\text_classification.py:105: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(

# %%
# usar este df, tendra la informacion con la columna. non_nan_rows
# Function to extract sentiment scores
def get_sentiment_score(sentiment_list, target_label):
    for sentiment_dict in sentiment_list[0]:  # Access the first (and only) element in the list
        if sentiment_dict['label'] == target_label:
            return sentiment_dict['score']
    return None

# Create separate columns for 'positive', 'neutral', and 'negative'
sentiment_menendez['positive_score'] = sentiment_menendez['sentiment'].apply(lambda x: get_sentiment_score(x, 'positive'))
sentiment_menendez['neutral_score'] = sentiment_menendez['sentiment'].apply(lambda x: get_sentiment_score(x, 'neutral'))
sentiment_menendez['negative_score'] = sentiment_menendez['sentiment'].apply(lambda x: get_sentiment_score(x, 'negative'))

# Print the modified DataFrame
sentiment_menendez.tail(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sentiment'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 9
#       6     return None
#       8 # Create separate columns for 'positive', 'neutral', and 'negative'
# ----> 9 sentiment_menendez['positive_score'] = sentiment_menendez['sentiment'].apply(lambda x: get_sentiment_score(x, 'positive'))
#      10 sentiment_menendez['neutral_score'] = sentiment_menendez['sentiment'].apply(lambda x: get_sentiment_score(x, 'neutral'))
#      11 sentiment_menendez['negative_score'] = sentiment_menendez['sentiment'].apply(lambda x: get_sentiment_score(x, 'negative'))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'sentiment'

# %%
def truncate_text(text):
    if isinstance(text, str):
        return text[:512]
    else:
        return text

# Apply the truncation function to the 'text' column
sentiment_menendez['text'] = sentiment_menendez['text'].apply(truncate_text)

# Filter out NaN values before applying sentiment analysis
non_nan_rows = sentiment_menendez.dropna(subset=['text'])
